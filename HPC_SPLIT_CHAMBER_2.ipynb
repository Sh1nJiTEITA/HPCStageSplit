# %% [markdown]
# # Расчет количества и теплоперепадов нерегулируемых ступеней ЦВД
#
# ## Исходные данные для первого отсека ЦВД
#
# |№|Наименование | Значение|
# |-| ------------------------------------------------------------------- | ----------------------------- |
# |1|Давление полного торможения после нерегулируемой ступени             | $$\ \bar {p}_0^{(1)} = 8.73 \ МПа$$      |
# |2|Энтальпия полного торможения перед первой нерегулируемой ступенью    | $\ \bar h_0^{(1)} = 3563.4 \ кДж/кг$   |
# |3|Частота вращения вала                                                | $\ n = 95 \ Гц$               |
# |4|Расход пара в группе ступеней                                        | $\ G_0^{(1)} = 38.88\  кг/с$        |
# |5|Давление за отсеком                                                  | $\ p_z^{(1)} = 1.8 \ МПа$           |
# |6|Внутренний КПД группы ступеней                                       | $\ \eta_{oi}^{(1)} = 0.846$        |
#
# Далее по расчету все переменные, относящиеся к полным параметрам имеют префикс f, например переменная fp_0 означает $\bar p_0$, аналогично и для других параметров

# %%
# Используемые для расчета библиотеки

# out1, row:209 green

# Для динамического вывода значений
from IPython.display import Math

# Для использования единиц измерения
from pint import Quantity as Q
import pint

# Для расчета термодинамических параметров
import API
#from API.API.lstr import API.lstr

# Для математических расчетов
import numpy as np

# Для построения графиков
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as ticker
# Out:
# API loaded

# %%
# Номер отсека
number = 2

# Объявление начальных переменных

# Давление полного торможения перед группой ступеней
fp_0        = Q(1.8, "MPa")

# Энтальпия полного торможения перед группой ступеней
fh_0        = Q(3145.1, "kJ/kg")

# Термодинамическая точка f0
fPoint_0    = API.ThPoint(p=fp_0, h=fh_0)

# Номинальная частота вращения вала
n           = Q(95, "1/s")

# Массовый расход через группу ступеней
G_0         = Q(38.88, "kg/s")

# Давление за группой ступеней
p_z         = Q(0.485, "MPa")

# Внутренний относительный КПД группы ступеней
etaHPC_oi   = Q(0.883, "")

# %% [markdown]
# ## Варируемые величины
#
# |№      | Наименование                                                          | Обозначение                               |
# | ----- | --------------------------------------------------------------------- | ----------------------------------------- |
# |1      |Степень реактивности первой нерегулируемой ступени в корне             | $$\ \rho_{к}^{(1)} = 0.03-0.07=0.05$$       |
# |2      |Эффективный угол выхода потока из сопловой решетки                     | $\ \alpha_{1эф}^{(1)} = 8-16\ ^\circ$     |
# |3      |Коэффициент скорости сопловой решетки                                  | $\ \varphi^{(1)} = 0.93-0.96=0.94$        |
# |4      |Коэффициент расхода сопловой решетки первой нерегулируемой ступени     | $\ \mu^{(1)} = 0.95-0.97=0.98$            |
# |5      |Перекрыша между высотами лопаток первой нерегулируемой ступени         | $\ \Delta^{(1)} = 0.003 \ м$              |

# %%
# Объявление варируемых переменных

# Степень реактивности первой нерегулируемой ступени в корне
rho_k       = Q(0.03, "")

# Эффективный угол выхода потока из сопловой решетки
alpha_1eef  = Q(16, "deg")

# Коэффициент скорости сопловой решетки
phi         = Q(np.mean([0.93,0.96]), "")

# Коэффициент расхода сопловой решетки первой нерегулируемой ступени
mu          = Q(np.mean([0.95,0.97]), "")

# Перекрыша между высотами лопаток первой нерегулируемой ступени 
Delta       = Q(0.003, "m")

# Предполагаемое количество ступеней
Z           = Q(6, '')

# %% [markdown]
# ## Алгоритм расчета
# ### 1. Задаемся средним диаметром первой нерегулируемой ступени $d_1^{(1)} = 0.6\ м$

# %%
# Средний диаметр первой нерегулируемой ступени
d_1 = Q(0.549, "m")

# %% [markdown]
# ### 2. Определяем энтропию пара за первой нерегулируемой ступенью

# %%
fs_0 = fPoint_0.s()

Math(r"\Large 2.\ \bar {s}_{0}^{(1)} = " + r"f(p={fp_0}, h={fh_0}) = {fs_0:~}".format(fp_0 = fp_0.m, fh_0 = fh_0.m, fs_0 = round(fs_0, 3)))
# Out:
# $\displaystyle \Large 2.\ \bar {s}_{0}^{(1)} = f(p=1.8, h=3145.1) = 7.017 kJ / K / kg$

# %% [markdown]
# ### 3. Определяем высоту первой нерегулируемой ступени
# Для этого задаемся величиной обратной верености $\theta = var$ и проводим итерационный расчет, в результате которого заданная и расчетная обратная веерность должна совпадать не менее чем на 0.1%, так же проверяем длину лопатки первой нерегулируемой ступени.
#
# 1. Задаем величину обратной веерности
#
#     $$\large{\theta = var}$$
#
# 2. Определяем степень реактивности на среднем диаметр
#
#     $$\large{\rho = \rho_{к} + \frac{1.8}{\theta + 1.8}}$$
#
# 3. Определяем располагаемый теплопеперад по параметрам торможения при оптимальном для первой ступени
#
#     $$\large{ \Bigg(\frac{u}{c_ф} \Bigg)_{опт} = \frac{\varphi \cdot \cos{\alpha_{1эф}}}{2 \sqrt{1-\rho}}}$$
#
# 4. Определяем располагаемый теплопеперад по параметрам торможения при оптимальном $\large \Big(\frac{u}{c_ф} \Big)_{опт}$ с помощью зависимости:
#
#     $$\large{\bar {H}_{01} = 12300\Bigg( \dfrac{ d_1}{ \Bigg(\dfrac{u}{c_ф}\Bigg)_{опт}}\dfrac{n}{50} \Bigg)^2}$$
#
# 5. Определяем теоретическое значение энтальпии за первой ступенью
#
#     $$\large{h_{2t} = \bar {h}_{0} - \bar H_{01}}$$
#
# 6. Определяем удальный объем пара за первой нерегулируемой ступенью при изоэнтропном процессе расширения по свойствам воды и водяного пара
#
#     $$\large{v_{2t} = f(h_{2t}, \bar s_0)}$$
#
# 7. Определяем высоту лопаток первой нерегулируемой ступени
#
#     $$ l_{11} = \frac{G_0 v_{2t} \big(u/c_{ф}\big)_{опт}}{\pi^2  d_1^2  n  \sqrt{1-\rho}\ \mu_1 \sin{\alpha_{1эф}}  }$$
#
# В расчете так же надо учесть тот факт, что изначально задаваемое количество ступеней влияет на конечный результат.

# %%
# 3.1. Величина обратной веерности
theta = 20
iterations_number = 0
percent_difference = 0.0
l_11 = 0
while (True):
    
    # 3.2. Определяем степень реактивности на среднем диаметре
    rho = rho_k + 1.8/(theta+1.8)
    
    # 3.3. Определяем оптимальное значение u/c_f
    uDIVu_cf = phi*np.cos(alpha_1eef)/(2*np.sqrt(1-rho))
    
    # 3.4. Определяем располагаемый теплопеперад по параметрам торможения при оптимальном
    # u/c_f для первой ступени 
    fH_01 = 12300 * np.power((d_1 * n)/(uDIVu_cf * 50), 2)
    fH_01.ito('kJ/kg')
    
    # 3.5. Определяем теоретическое значение энтальпии за первой ступенью
    h_2t = fh_0 - fH_01
    
    # 3.6. Определяем удальный объем пара за первой нерегулируемой ступенью при
    # изоэнтропном процессе расширения по свойствам воды и водяного пара
    Point_2t = API.TCPv2.ThPoint(h=h_2t, s=fPoint_0.s())
    v_2t = Point_2t.v()
    
    # 3.7. Определеяем высоту первой нерегулируемой ступени
    l_11 = (G_0 * v_2t * uDIVu_cf)/(np.power(np.pi*d_1,2) * n * np.sqrt(1-rho) * np.sin(alpha_1eef) * mu)
    l_11.ito("m")
    # 3.8. Определяем окончательное значение обратной веерности и проверяем его
    
    # Проверка условия 
    # Если получившаяся величина больше, чем заданная
    if (d_1/l_11 > theta):
        # То вычитаем отношение из единицы
        percent_difference = (1 - theta/(d_1/l_11)) 
    # Если величина меньше, чем заданная
    else:
        # То вычитаем из отношения единицу
        percent_difference = (theta/(d_1/l_11) - 1)
    
    # Если условие выполнилось - выходим из цикла
    if (np.abs(percent_difference) < 0.01):
        break
    # Иначе добавляем итерацию и меняем приближающее значение на найденное в процессе цикла
    else:
        iterations_number += 1
        theta = (d_1/l_11)

# %%
Math(
    # 3.2. theta
    API.lstr(r"3.2.\ \theta = [a]").dformat(a=theta).get_large() +
    
    # 3.3. rho
    API.lstr(r"3.3.\ \rho = \rho_{к} + \frac{1.8}{\theta + 1.8} = [rho_k] + \frac{1.8}{[theta] + 1.8} = [rho]").dformat(rho_k = rho_k, theta = theta, rho=rho).get_large() +
    
    # 3.4. fH_01 = 12.3 * np.power((d_1 * n)/(uDIVu_cf * 50), 2)
    API.lstr(r"3.4.\ \bar H_{01}=12300 \Bigg( \frac{d_1}{(u/c)_{опт}} \frac{n}{50} \Bigg)^2 = 12300 \Bigg( \frac{[d_1]}{[uDIVc]} \frac{[n]}{50} \Bigg)^2 = [fH_01] \ кДж/кг").dformat(d_1=d_1, uDIVc=uDIVu_cf, n=n,fH_01=fH_01.to("kJ/kg")).get_large() +
    
    # 3.5. h_2t = fh_0 - fH_01
    API.lstr(r"3.5.\ h_{2t} = \bar h_0 - \bar H_{01} = [fh_0] - [fH_01] = [h_2t]\ кДж/кг").dformat(fh_0=fh_0, fH_01=fH_01, h_2t=h_2t).get_large() +
    
    # 3.6. v_2t = Point_2t.v() /  Point_2t = API.TCPv2.ThPoint(h=h_2t, s=fPoint_0.s())
    API.lstr(r"3.6.\ v_{2t} = f\Bigg(\begin{matrix}h_{2t} = [h_2t] \\ \bar s_0 = [fs_0]\end{matrix}\Bigg)  = [v_2t]\ м^3/кг").dformat(h_2t=h_2t,fs_0=fs_0,v_2t=v_2t).get_large() + 
    
    # 3.7. l_11 = (G_0 * v_2t * uDIVu_cf)/(np.power(np.pi*d_1,2) * n * np.sqrt(1-rho) * np.sin(alpha_1eef) * mu)
    API.lstr(r"3.7.\ l_{11} = \frac{G_0\ v_{2t} \ (u/c_ф)_{опт} }{\pi^2 \ d_1^2\ n\ \sqrt{1-\rho}\ \mu \ \sin{\alpha_{1эф}}} = \frac{[G_0]\cdot [v_2t]\cdot [uDIVc]}{\pi^2\cdot [d_1]^2\cdot [n]\ \sqrt{1-[rho]}\cdot [mu]\cdot \sin{[alpha_1eef]^\circ}} = [l_11]\ м").dformat(G_0=G_0, v_2t=v_2t, uDIVc=uDIVu_cf,d_1=d_1,n=n,rho=rho,mu=mu,alpha_1eef=alpha_1eef, l_11=l_11).get_large()+
    
    API.lstr(r"3.8.\ При\ расчете\ высоте\ лопатки\ и\ определения\ веерности\ проделано\ [a] \ итерации\ и\ погрешность\ составляет\ [b] \%").dformat(a=iterations_number, b=percent_difference * 100)
)
# Out:
# $\displaystyle \Large{3.2.\ \theta = 10.71} \\ \ \\\Large{3.3.\ \rho = \rho_{к} + \frac{1.8}{\theta + 1.8} = 0.03 + \frac{1.8}{10.71 + 1.8} = 0.174} \\ \ \\\Large{3.4.\ \bar H_{01}=12300 \Bigg( \frac{d_1}{(u/c)_{опт}} \frac{n}{50} \Bigg)^2 = 12300 \Bigg( \frac{0.549}{0.5} \frac{95}{50} \Bigg)^2 = 53.6 \ кДж/кг} \\ \ \\\Large{3.5.\ h_{2t} = \bar h_0 - \bar H_{01} = 3145.1 - 53.6 = 3091.5\ кДж/кг} \\ \ \\\Large{3.6.\ v_{2t} = f\Bigg(\begin{matrix}h_{2t} = 3091.5 \\ \bar s_0 = 7.0172\end{matrix}\Bigg)  = 0.18\ м^3/кг} \\ \ \\\Large{3.7.\ l_{11} = \frac{G_0\ v_{2t} \ (u/c_ф)_{опт} }{\pi^2 \ d_1^2\ n\ \sqrt{1-\rho}\ \mu \ \sin{\alpha_{1эф}}} = \frac{38.88\cdot 0.18\cdot 0.5}{\pi^2\cdot 0.549^2\cdot 95\ \sqrt{1-0.174}\cdot 0.96\cdot \sin{16^\circ}} = 0.0516\ м} \\ \ \\3.8.\ При\ расчете\ высоте\ лопатки\ и\ определения\ веерности\ проделано\ 2 \ итерации\ и\ погрешность\ составляет\ 0.659 \%$

# %% [markdown]
# ### 4. Определение высоту рабочей лопатки первой нерегулирумой ступени

# %%
# Высота рабочей лопатки
l_21 = l_11 + Delta
l_21.ito('m')

# %%
Math(
    API.lstr(r"4.\ l_{21} = l_{11} + \Delta = [l_11] + [Delta] = [l_21]\ м").dformat(l_11=l_11,Delta=Delta,l_21=l_21).get_large()
)
# Out:
# $\displaystyle \Large{4.\ l_{21} = l_{11} + \Delta = 0.0516 + 0.003 = 0.0546\ м} \\ \ \\$

# %% [markdown]
# ### 5. Определение корневого диаметра ступени

# %%
# Корневой диаметр ступени
d_k = d_1 - l_21
d_k.ito('m')

# %%
Math(
    API.lstr(r"5.\ d_к = d_1 - l_{21} = [d_1] - [l_21] = [d_k]\ м").dformat(d_1=d_1,l_21=l_21,d_k=d_k).get_large()
)
# Out:
# $\displaystyle \Large{5.\ d_к = d_1 - l_{21} = 0.549 - 0.0546 = 0.494\ м} \\ \ \\$

# %% [markdown]
# ### 6. Определение параметров пара за последней ступенью группы
#
# 1. Значение энтальпии пара при изоэнтропном расширении пара в ЦВД
#
#     $$\large{h_{zt} = f\bigg(\begin{matrix}p_z \\ \bar s_0 \end{matrix}\bigg)}$$
#
# 2. Теоретический перепад на отсек нерегулируемых ступеней группы
#
#     $$\large{\bar H_0 = \bar h_0 - h_{zt}}$$
#
# 3. Действительный теплоперепад на отсек нерегулирумых ступеней группы
#
#     $$\large{H_i = \bar H_0 \cdot \eta_{oi}^{(1)}}$$
#
# 4. Действительное значение энтальпии за последней ступенью группы
#
#     $$\large{h_z = \bar h_0 - H_i}$$
#
# 5. Действительный объем за последней ступенью группы
#
#     $$\large{v_{2z} = f\bigg(\begin{matrix}p_z \\ h_z \end{matrix}\bigg)}$$

# %%
# 6.1. Значение энтальпии пара при изоэнтропном расширении пара в ЦВД:
# Термодинамическая точка zt
Point_zt = API.TCPv2.ThPoint(p=p_z, s=fPoint_0.s())
# Энтальпия
h_zt = Point_zt.h()

# 6.2. Теоретический перепад на отсек нерегулируемых ступеней ЦВД:
fH_0 = fh_0 - h_zt

# 6.3. Действительный теплоперепад на отсек нерегулируемых ступеней ЦВД
H_i = fH_0 * etaHPC_oi

# 6.4. Действительное значение энтальпии за ЦВД (за последней ступенью)
h_z = fh_0 - H_i

# 6.5 Действительный объем за ЦВД (за последней ступенью)
# Термодинамическая точка 2z
Point_2z = API.TCPv2.ThPoint(p=p_z, h=h_z)
v_2z = Point_2z.v()

# %%
Math(
    # 6.1
    API.lstr(r"6.1.\ h_{zt} = f\bigg(\begin{matrix}p_z=[p_z] \\ \bar s_0=[fs_0] \end{matrix}\bigg) = [h_zt]\ кДж/кг").dformat(p_z=p_z,fs_0=fs_0,h_zt=h_zt).get_large() +
    # 6.2
    API.lstr(r"6.2.\ \bar H_0 = \bar h_0 - h_{zt} = [fh_0] - [h_zt] = [fH_0]\ кДж/кг").dformat(fh_0=fh_0,h_zt=h_zt,fH_0=fH_0).get_large() +
    # 6.3
    API.lstr(r"6.3.\ H_i = \bar H_0 \cdot \eta_{oi}^{(1)} = [fH_0] \cdot [eta] = [H_i]\ кДж/кг").dformat(fH_0=fH_0,eta=etaHPC_oi,H_i=H_i).get_large() +
    # 6.4
    API.lstr(r"6.4.\ h_z = \bar h_0 - H_i = [fh_0] - [H_i] = [h_z]\ кДж/кг").dformat(fh_0=fh_0,H_i=H_i,h_z=h_z).get_large() +
    # 6.5
    API.lstr(r"6.5.\ v_{2z} = f\bigg(\begin{matrix}p_z=[p_z] \\ h_z=[h_z] \end{matrix}\bigg)=[v_2z]\ м^3/кг").dformat(p_z=p_z,h_z=h_z,v_2z=v_2z).get_large()
)
# Out:
# $\displaystyle \Large{6.1.\ h_{zt} = f\bigg(\begin{matrix}p_z=0.485 \\ \bar s_0=7.0172 \end{matrix}\bigg) = 2829.0\ кДж/кг} \\ \ \\\Large{6.2.\ \bar H_0 = \bar h_0 - h_{zt} = 3145.1 - 2829.0 = 316.1\ кДж/кг} \\ \ \\\Large{6.3.\ H_i = \bar H_0 \cdot \eta_{oi}^{(1)} = 316.1 \cdot 0.883 = 279.1\ кДж/кг} \\ \ \\\Large{6.4.\ h_z = \bar h_0 - H_i = 3145.1 - 279.1 = 2866.0\ кДж/кг} \\ \ \\\Large{6.5.\ v_{2z} = f\bigg(\begin{matrix}p_z=0.485 \\ h_z=2866.0 \end{matrix}\bigg)=0.443\ м^3/кг} \\ \ \\$

# %% [markdown]
# ### 7. Определение высоты рабочей лопатки последней ступени
# Так как объем при высоких давлениях изменяются практически линейно, то можно принять закон изменения диаметров/высот лопаток линейным. Для начала необходимо найти высоту лопатки последней ступени в группе из уравнения:
#
# $$ l_{2z}^2 + l_{2z} \ d_к = l_{21} \ d_{21} \frac{v_{2z}}{v_{2t}}$$
#
# $$ l_{2z} = \frac{-d_к \pm \sqrt{d_к^2 + 4 l_{21}\ d_{21} \frac{v_{2z}}{v_{2t}}}}{2}$$

# %%
# 7 Высота рабочей лопатки последней ступени
l_2z = (-d_k + np.sqrt(d_k**2 + 4*l_21*d_1*v_2z/v_2t))/2

# %%
Math(
    API.lstr(r"l_{2z} = \frac{-d_к + \sqrt{d_к^2 + 4 l_{21}\ d_{21} \frac{v_{2z}}{v_{2t}}}}{2} = \frac{-[d_k] + \sqrt{[d_k]^2 + 4 \cdot [l_21] \cdot [d_21] \frac{[v_2z]}{[v_2t]}}}{2} = [l_2z]\ м").dformat(d_k=d_k,l_21=l_21,d_21=d_1,v_2z=v_2z,v_2t=v_2t,l_2z=l_2z).get_large()
)
# Out:
# $\displaystyle \Large{l_{2z} = \frac{-d_к + \sqrt{d_к^2 + 4 l_{21}\ d_{21} \frac{v_{2z}}{v_{2t}}}}{2} = \frac{-0.494 + \sqrt{0.494^2 + 4 \cdot 0.0546 \cdot 0.549 \frac{0.443}{0.18}}}{2} = 0.12\ м} \\ \ \\$

# %% [markdown]
# ### 8. Определение среднего диаметра последней ступени группы
#
# $$ \large{d_{2z} = d_к + l_{2z}} $$

# %%
# 8 Средний диаметр последней ступени группы
d_2z = d_k + l_2z

# %%
Math(
    API.lstr(r"d_{2z} = d_к + l_{2z} = [d_k] + [l_2z] = [d_2z]\ м").dformat(d_k=d_k,l_2z=l_2z,d_2z=d_2z).get_large()
)
# Out:
# $\displaystyle \Large{d_{2z} = d_к + l_{2z} = 0.494 + 0.12 = 0.614\ м} \\ \ \\$

# %% [markdown]
# ### 9. Определяем основные параметры первой и последней ступени
# 1. Определение обратной вверности в первой и последней ступени группы
#
#     $$ \theta_1 = \frac{l_{21} + d_к }{l_21} $$
#     $$ \theta_z = \frac{l_{2z} + d_к }{l_2z} $$
#
# 2. Определение степени реактивности на среднем диаметре в первой и последней ступени группы
#
#     $$ \rho_1 = \rho_к + \frac{1.8}{\theta_1 + 1.8} $$
#     $$ \rho_z = \rho_к + \frac{1.8}{\theta_z + 1.8} $$
#
# 3. Определение оптимального значения $u/c_ф$
#
#     $$ \bigg(\frac{u}{c_ф}\bigg)_1 = \frac{\varphi \cos{\alpha_{1эф}}}{2\sqrt{1-\rho_1}}$$
#     $$ \bigg(\frac{u}{c_ф}\bigg)_z = \frac{\varphi \cos{\alpha_{1эф}}}{2\sqrt{1-\rho_z}}$$

# %%
# 9.1 Обратная вверность в первой и последней ступени
theta_1 = (l_21 + d_k)/l_21
theta_z = (l_2z + d_k)/l_2z

# 9.2 Степень реактивности в первой и последней ступени
rho_1 = rho_k + 1.8/(theta_1 + 1.8)
rho_z = rho_k + 1.8/(theta_z + 1.8)

# 9.3 Оптимальное значение u/c_ф
uDIVu_1 = phi*np.cos(alpha_1eef)/(2*np.sqrt(1-rho_1))
uDIVu_z = phi*np.cos(alpha_1eef)/(2*np.sqrt(1-rho_z))

# %%
Math(
    API.lstr(r"9.1.1\ \theta_1 = \frac{l_{21} + d_к }{l_21} = \frac{[l_21] + [d_k]}{[l_21]} = [theta_1]").dformat(l_21=l_21,d_k=d_k,theta_1=theta_1).get_large() +
    API.lstr(r"9.1.1\ \theta_z = \frac{l_{2z} + d_к }{l_2z} = \frac{[l_2z] + [d_k]}{[l_2z]} = [theta_z]").dformat(l_2z=l_21,d_k=d_k,theta_z=theta_z).get_large() + 
    
    API.lstr(r"\\ \  \\") + 
    
    API.lstr(r"9.2.1\ \rho_1 = \rho_к + \frac{1.8}{\theta_1 + 1.8} = [rho_k] + \frac{1.8}{[theta_1] + 1.8} = [rho_1]").dformat(rho_k=rho_k, theta_1=theta_1,rho_1=rho_1).get_large() +
    API.lstr(r"9.2.2\ \rho_z = \rho_к + \frac{1.8}{\theta_z + 1.8} = [rho_k] + \frac{1.8}{[theta_z] + 1.8} = [rho_z]").dformat(rho_k=rho_k, theta_z=theta_z,rho_z=rho_z).get_large() + 
    
    API.lstr(r"\\ \  \\") + 
    
    API.lstr(r"9.3.1\ \Bigg(\frac{u}{c_ф}\Bigg)_1 = \frac{\varphi \cos{\alpha_{1эф}}}{2\sqrt{1-\rho_1}} = \frac{[phi] \cdot \cos{[alpha_1eef]^\circ}}{2\sqrt{1-[rho_1]}} = [uDIVc]").dformat(phi=phi,alpha_1eef=alpha_1eef,rho_1=rho_1, uDIVc=uDIVu_1).get_large() +
    API.lstr(r"9.3.2\ \Bigg(\frac{u}{c_ф}\Bigg)_z = \frac{\varphi \cos{\alpha_{1эф}}}{2\sqrt{1-\rho_z}} = \frac{[phi] \cdot \cos{[alpha_1eef]^\circ}}{2\sqrt{1-[rho_z]}} = [uDIVc]").dformat(phi=phi,alpha_1eef=alpha_1eef,rho_z=rho_z, uDIVc=uDIVu_z).get_large()
    
)
# Out:
# $\displaystyle \Large{9.1.1\ \theta_1 = \frac{l_{21} + d_к }{l_21} = \frac{0.0546 + 0.494}{0.0546} = 10.06} \\ \ \\\Large{9.1.1\ \theta_z = \frac{l_{2z} + d_к }{l_2z} = \frac{0.0546 + 0.494}{0.0546} = 5.127} \\ \ \\\\ \  \\\Large{9.2.1\ \rho_1 = \rho_к + \frac{1.8}{\theta_1 + 1.8} = 0.03 + \frac{1.8}{10.06 + 1.8} = 0.182} \\ \ \\\Large{9.2.2\ \rho_z = \rho_к + \frac{1.8}{\theta_z + 1.8} = 0.03 + \frac{1.8}{5.127 + 1.8} = 0.29} \\ \ \\\\ \  \\\Large{9.3.1\ \Bigg(\frac{u}{c_ф}\Bigg)_1 = \frac{\varphi \cos{\alpha_{1эф}}}{2\sqrt{1-\rho_1}} = \frac{0.945 \cdot \cos{16^\circ}}{2\sqrt{1-0.182}} = 0.502} \\ \ \\\Large{9.3.2\ \Bigg(\frac{u}{c_ф}\Bigg)_z = \frac{\varphi \cos{\alpha_{1эф}}}{2\sqrt{1-\rho_z}} = \frac{0.945 \cdot \cos{16^\circ}}{2\sqrt{1-0.29}} = 0.539} \\ \ \\$

# %% [markdown]
# ### 10. Выполнение разбивки теплоперепадов
#
# 1. Предполагаем, что средний диаметр ступеней и высота лопаток высота лопаток изменяются вдоль ЦВД линейно. Так же учтем, что удобнее использовать нумерацию для ступеней с 1, поэтому:
#     1. Для диаметров:
#         $$ \large{d(z_i) = \bigg(\frac{d_z-d_1}{Z-1}\bigg)z_i + \frac{d_1Z - d_{2z}}{Z-1}}$$
#     2. Для высот лопаток:
#         $$ \large{l(z_i) = \bigg(\frac{l_z-l_{21}}{Z-1}\bigg)z_i + \frac{l_{21}Z-l_{2z}}{Z_1}}$$
# 2. Определяем обратную веерность для каждой ступени
#     $$ \large{\theta_i = \frac{l_i + d_к}{l_i}}$$
# 3. Определяем степень реактивности на среднем диаметре для каждой ступени
#     $$ \large{\rho_i = \rho_к + \frac{1.8}{\theta_i + 1.8}}$$
# 4. Для каждой ступени определяем опимальную величину $u/c_ф$
#     $$ \large{\bigg( \frac{u}{c_ф}\bigg)_{оптi} = \frac{\varphi \cos{\alpha_{1эф}}}{2\sqrt{1-\rho_i}}}$$
# 5. Для каждой ступени определяем теплоперепад по статическим параметрам
#     $$ \large{H_{0i} = 12300 \Bigg(\frac{d_i}{(u/c_ф)_{оптi}} \frac{n}{50}\Bigg)^2K_i}$$
#     $$ при \ i>1 \dashrightarrow K_i = 0.95 $$
#     $$ при \ i=1 \dashrightarrow K_i = 1.00 $$
#
# 6. Определяем среднее арифметическое значение теплоперепадов
#     $$ \large{H_{0ср} = \frac{1}{Z}\displaystyle\sum_{i=1}^ZH_{0i}} $$
# 7. Определяем коэффициент возврата теплоты
#     $$ \large{q_t = 4.8\cdot10^{-4}(1-\eta^{(1)}_{oi})\bar H_0\frac{Z-1}{Z}} $$
# 8. Новое значение количества ступеней ЦВД
#     $$ \large{Z_{нов}=(1+q_t) \frac{\bar H_0}{H_{0ср}}}$$

# %%
## 10.1.1, 10.1.2
# Коэффициент k для функции диаметра
k_d = (d_2z - d_1)/(Z.m-1)
b_d = (d_1*Z.m - d_2z)/(Z.m-1)

# Коэффициент k для функции длины лопатки
k_l = (l_2z - l_21)/(Z.m-1)
b_l = (l_21*Z.m - l_2z)/(Z.m-1)

# Функция для определения диаметра по номеру ступени
def d(z_i):
    return k_d*z_i + b_d

# Функция для определения длины лопатки по номеру ступени
def l(z_i):
    return k_l*z_i + b_l

# Перечислим номера ступеней в данном векторе
stages_number_vec = np.arange(1, Z.m+1, 1)

# Диаметры каждой ступени
d_vec = d(stages_number_vec)

# Длины сопловых лопаток каждой ступени
l_vec = l(stages_number_vec)

# %%
d_vec_str = API.lstr(r"\begin{matrix}")
for i in range(0, len(d_vec)):
    d_vec_str += API.lstr(r"d_{[it]} = k_d z_{[it]} + b_d = [k_d] \cdot [z] + [b_d] = [d_i]\ м ").dlformat(it=i+1,z=i+1,d_i=d_vec[i],k_d=k_d,b_d=b_d)
    d_vec_str += API.lstr(r"&|\ \ \ l_{[it]} = k_l z_{[it]} + b_l = [k_l] \cdot [z] + [b_l] = [l_i]\ м  \\").dlformat(it=i+1,k_l=k_l,z=i+1,b_l=b_l,l_i=l_vec[i])
    
Math(
    API.lstr(r"\Large{10.1} \\ ") + 
    API.lstr(d_vec_str + r"\end{matrix}").get_large()
)
# Out:
# $\displaystyle \Large{10.1} \\ \Large{\begin{matrix}d_{1} = k_d z_{1} + b_d = 0.0130 \cdot 1 + 0.536 = 0.549\ м &|\ \ \ l_{1} = k_l z_{1} + b_l = 0.0130 \cdot 1 + 0.0415 = 0.0546\ м  \\d_{2} = k_d z_{2} + b_d = 0.0130 \cdot 2 + 0.536 = 0.562\ м &|\ \ \ l_{2} = k_l z_{2} + b_l = 0.0130 \cdot 2 + 0.0415 = 0.0676\ м  \\d_{3} = k_d z_{3} + b_d = 0.0130 \cdot 3 + 0.536 = 0.575\ м &|\ \ \ l_{3} = k_l z_{3} + b_l = 0.0130 \cdot 3 + 0.0415 = 0.0807\ м  \\d_{4} = k_d z_{4} + b_d = 0.0130 \cdot 4 + 0.536 = 0.588\ м &|\ \ \ l_{4} = k_l z_{4} + b_l = 0.0130 \cdot 4 + 0.0415 = 0.0937\ м  \\d_{5} = k_d z_{5} + b_d = 0.0130 \cdot 5 + 0.536 = 0.601\ м &|\ \ \ l_{5} = k_l z_{5} + b_l = 0.0130 \cdot 5 + 0.0415 = 0.107\ м  \\d_{6} = k_d z_{6} + b_d = 0.0130 \cdot 6 + 0.536 = 0.614\ м &|\ \ \ l_{6} = k_l z_{6} + b_l = 0.0130 \cdot 6 + 0.0415 = 0.120\ м  \\\end{matrix}} \\ \ \\$

# %%
# 10.2
# Обратная вверность для каждой ступени
theta_vec = (l_vec + d_k)/l_vec

# 10.3
# Степень реактивности на среднем диаметре для каждой ступени
rho_vec = rho_k + 1.8/(theta_vec + 1.8)

# %%
theta_vec_str = r"\begin{matrix}"
for i in range(0, len(theta_vec)):
    theta_vec_str += API.lstr(r"\theta_{[i]} = \dfrac{l_{[i]} + d_к}{l_{[i]}} = \dfrac{[l_i] + [d_k]}{[l_i]}=[theta]").dlformat(i=i+1,theta=theta_vec[i],l_i=l_vec[i],d_k=d_k)
    theta_vec_str += API.lstr(r"&\ \ \ \ \ \ \ \ \rho_{[i]}=\rho_к+\dfrac{1.8}{1.8+\theta_{[i]}}=[rho_k]+\dfrac{1.8}{1.8+[theta_i]}=[rho_i] \\ ").dlformat(i=i+1,rho_k=rho_k,theta_i=theta_vec[i],rho_i=rho_vec[i])
    theta_vec_str += API.lstr(r"& \ \ \\")
Math(
    API.lstr(r"10.2\ \& \ 10.3 \\ ").get_large() + 
    API.lstr(theta_vec_str + r"\end{matrix}").get_large()
)
# Out:
# $\displaystyle \Large{10.2\ \& \ 10.3 \\ } \\ \ \\\Large{\begin{matrix}\theta_{1} = \dfrac{l_{1} + d_к}{l_{1}} = \dfrac{0.0546 + 0.494}{0.0546}=10.06&\ \ \ \ \ \ \ \ \rho_{1}=\rho_к+\dfrac{1.8}{1.8+\theta_{1}}=0.03+\dfrac{1.8}{1.8+10.06}=0.182 \\ & \ \ \\\theta_{2} = \dfrac{l_{2} + d_к}{l_{2}} = \dfrac{0.0676 + 0.494}{0.0676}=8.312&\ \ \ \ \ \ \ \ \rho_{2}=\rho_к+\dfrac{1.8}{1.8+\theta_{2}}=0.03+\dfrac{1.8}{1.8+8.312}=0.208 \\ & \ \ \\\theta_{3} = \dfrac{l_{3} + d_к}{l_{3}} = \dfrac{0.0807 + 0.494}{0.0807}=7.130&\ \ \ \ \ \ \ \ \rho_{3}=\rho_к+\dfrac{1.8}{1.8+\theta_{3}}=0.03+\dfrac{1.8}{1.8+7.130}=0.232 \\ & \ \ \\\theta_{4} = \dfrac{l_{4} + d_к}{l_{4}} = \dfrac{0.0937 + 0.494}{0.0937}=6.276&\ \ \ \ \ \ \ \ \rho_{4}=\rho_к+\dfrac{1.8}{1.8+\theta_{4}}=0.03+\dfrac{1.8}{1.8+6.276}=0.253 \\ & \ \ \\\theta_{5} = \dfrac{l_{5} + d_к}{l_{5}} = \dfrac{0.107 + 0.494}{0.107}=5.632&\ \ \ \ \ \ \ \ \rho_{5}=\rho_к+\dfrac{1.8}{1.8+\theta_{5}}=0.03+\dfrac{1.8}{1.8+5.632}=0.272 \\ & \ \ \\\theta_{6} = \dfrac{l_{6} + d_к}{l_{6}} = \dfrac{0.120 + 0.494}{0.120}=5.127&\ \ \ \ \ \ \ \ \rho_{6}=\rho_к+\dfrac{1.8}{1.8+\theta_{6}}=0.03+\dfrac{1.8}{1.8+5.127}=0.290 \\ & \ \ \\\end{matrix}} \\ \ \\$

# %%
# 10.4. Для каждой ступени определяем величину u/c_f
uDIVc_f_vec = phi*np.cos(alpha_1eef)/(2*np.sqrt(1-rho_vec))

# 10.5 Теплоперепад по статическим параметрам для каждой ступени
# Вектор коэффициентов K_i
K_vec = np.full(Z.m, 0.95)
#K_vec[0] = 1.0

H_vec = 12300 * (d_vec/uDIVc_f_vec)**2 * (n/50)**2 * K_vec
H_vec.ito('kJ/kg')

# %%
H_vec_str = API.lstr(r"\begin{matrix}")
for i in range(0, len(H_vec)):
    H_vec_str += API.lstr(r"\Bigg(\dfrac{u}{c_ф}\Bigg)_{[i]} = \dfrac{\varphi\cos{\alpha_{1эф}}}{2\sqrt{1-\rho_{[i]}}} = \dfrac{[phi]\cos{[alpha_1eef]^\circ}}{2\sqrt{1-[rho_i]}}=[uDIVc_i]").dlformat(i=i+1,phi=phi,alpha_1eef=alpha_1eef,rho_i=rho_vec[i],uDIVc_i=uDIVc_f_vec[i])
    H_vec_str += API.lstr(r"&\ \ \ \ \ \ \ \ \  H_{0[i]} = 12300 \Bigg(\dfrac{d_[i]}{(u/c_ф)_{опт[i]}} \dfrac{n}{50}\Bigg)^2K_[i] = 12300\Bigg(\dfrac{[d_i]}{[uDIVc_i]}\dfrac{[n]}{50}\Bigg)^2[K_i]=[H_0i]\ кДж/кг \\ ").dlformat(i=i+1,d_i=d_vec[i],n=n,K_i=K_vec[i],uDIVc_i=uDIVc_f_vec[i],H_0i=H_vec[i])
    H_vec_str += API.lstr(r"& \ \ \\")
Math(
    API.lstr(r"10.4\ \& \ 10.5 \\").get_large() + 
    API.lstr(H_vec_str + r"\end{matrix}").get_large()
)
# Out:
# $\displaystyle \Large{10.4\ \& \ 10.5 \\} \\ \ \\\Large{\begin{matrix}\Bigg(\dfrac{u}{c_ф}\Bigg)_{1} = \dfrac{\varphi\cos{\alpha_{1эф}}}{2\sqrt{1-\rho_{1}}} = \dfrac{0.945\cos{16^\circ}}{2\sqrt{1-0.182}}=0.502&\ \ \ \ \ \ \ \ \  H_{01} = 12300 \Bigg(\dfrac{d_1}{(u/c_ф)_{опт1}} \dfrac{n}{50}\Bigg)^2K_1 = 12300\Bigg(\dfrac{0.549}{0.502}\dfrac{95}{50}\Bigg)^20.95=50.43\ кДж/кг \\ & \ \ \\\Bigg(\dfrac{u}{c_ф}\Bigg)_{2} = \dfrac{\varphi\cos{\alpha_{1эф}}}{2\sqrt{1-\rho_{2}}} = \dfrac{0.945\cos{16^\circ}}{2\sqrt{1-0.208}}=0.510&\ \ \ \ \ \ \ \ \  H_{02} = 12300 \Bigg(\dfrac{d_2}{(u/c_ф)_{опт2}} \dfrac{n}{50}\Bigg)^2K_2 = 12300\Bigg(\dfrac{0.562}{0.510}\dfrac{95}{50}\Bigg)^20.95=51.16\ кДж/кг \\ & \ \ \\\Bigg(\dfrac{u}{c_ф}\Bigg)_{3} = \dfrac{\varphi\cos{\alpha_{1эф}}}{2\sqrt{1-\rho_{3}}} = \dfrac{0.945\cos{16^\circ}}{2\sqrt{1-0.232}}=0.518&\ \ \ \ \ \ \ \ \  H_{03} = 12300 \Bigg(\dfrac{d_3}{(u/c_ф)_{опт3}} \dfrac{n}{50}\Bigg)^2K_3 = 12300\Bigg(\dfrac{0.575}{0.518}\dfrac{95}{50}\Bigg)^20.95=51.97\ кДж/кг \\ & \ \ \\\Bigg(\dfrac{u}{c_ф}\Bigg)_{4} = \dfrac{\varphi\cos{\alpha_{1эф}}}{2\sqrt{1-\rho_{4}}} = \dfrac{0.945\cos{16^\circ}}{2\sqrt{1-0.253}}=0.525&\ \ \ \ \ \ \ \ \  H_{04} = 12300 \Bigg(\dfrac{d_4}{(u/c_ф)_{опт4}} \dfrac{n}{50}\Bigg)^2K_4 = 12300\Bigg(\dfrac{0.588}{0.525}\dfrac{95}{50}\Bigg)^20.95=52.84\ кДж/кг \\ & \ \ \\\Bigg(\dfrac{u}{c_ф}\Bigg)_{5} = \dfrac{\varphi\cos{\alpha_{1эф}}}{2\sqrt{1-\rho_{5}}} = \dfrac{0.945\cos{16^\circ}}{2\sqrt{1-0.272}}=0.532&\ \ \ \ \ \ \ \ \  H_{05} = 12300 \Bigg(\dfrac{d_5}{(u/c_ф)_{опт5}} \dfrac{n}{50}\Bigg)^2K_5 = 12300\Bigg(\dfrac{0.601}{0.532}\dfrac{95}{50}\Bigg)^20.95=53.78\ кДж/кг \\ & \ \ \\\Bigg(\dfrac{u}{c_ф}\Bigg)_{6} = \dfrac{\varphi\cos{\alpha_{1эф}}}{2\sqrt{1-\rho_{6}}} = \dfrac{0.945\cos{16^\circ}}{2\sqrt{1-0.290}}=0.539&\ \ \ \ \ \ \ \ \  H_{06} = 12300 \Bigg(\dfrac{d_6}{(u/c_ф)_{опт6}} \dfrac{n}{50}\Bigg)^2K_6 = 12300\Bigg(\dfrac{0.614}{0.539}\dfrac{95}{50}\Bigg)^20.95=54.78\ кДж/кг \\ & \ \ \\\end{matrix}} \\ \ \\$

# %%
# 10.6 Среднее значение теплоперепада за группу ступеней
H_0ave = np.mean(H_vec)

# %%
H_0_sum_str = API.lstr(r"[a]").dformat(a=H_vec[0])
for i in range(1, len(H_vec)):
    H_0_sum_str += API.lstr("+[a]").dformat(a=H_vec[i])

Math(
   API.lstr( API.lstr(r"10.6\ H_{0ср} = \frac{") + H_0_sum_str + API.lstr(r"}{[Z]} = [H_0ave]\ кДж/кг").dformat(Z=Z,H_0ave=H_0ave)).get_large()
)
# Out:
# $\displaystyle \Large{10.6\ H_{0ср} = \frac{50.43+51.16+51.97+52.84+53.78+54.78}{6} = 52.49\ кДж/кг} \\ \ \\$

# %%
# 10.7 Коэффициент возврата теплоты
q_t_k = Q(4.8*10**(-4), 'kg/kJ')
q_t = q_t_k * (1 - etaHPC_oi)*H_0ave * (Z.m-1)/Z.m

# %%
Math(
    API.lstr(r"10.7\ q_t=4.8\cdot10^{-4}(1-\eta^{(1)}_{oi})H_{0ср}\dfrac{Z-1}{Z}=4.8\cdot10^{-4}(1-[eta])\cdot[H_0ave]\dfrac{[Z]-1}{[Z]} = [q_t]").dformat(eta=etaHPC_oi,H_0ave=H_0ave,Z=Z,q_t=q_t).get_large()
)
# Out:
# $\displaystyle \Large{10.7\ q_t=4.8\cdot10^{-4}(1-\eta^{(1)}_{oi})H_{0ср}\dfrac{Z-1}{Z}=4.8\cdot10^{-4}(1-0.883)\cdot52.49\dfrac{6-1}{6} = 0.00246} \\ \ \\$

# %%
# 10.8 Уточненное количество ступеней группы
Z_new = fH_0/H_0ave * (1+q_t)
Z_new.ito('')

# %%
Math(
    API.lstr(r"10.8\ Z_{нов}=\dfrac{\bar H_0}{H_{0ср}}(1+q_t) = \dfrac{[fH_0]}{[H_0ave]}(1+[q_t]) = [Z_new]").dformat(fH_0=fH_0,H_0ave=H_0ave,q_t=q_t,Z_new=Z_new).get_large()
)
# Out:
# $\displaystyle \Large{10.8\ Z_{нов}=\dfrac{\bar H_0}{H_{0ср}}(1+q_t) = \dfrac{316.1}{52.49}(1+0.00246) = 6.036} \\ \ \\$

# %% [markdown]
# ### 11. Определение невязки после разбивки теплоперепадов
# $$ \Delta_H = \dfrac{\bar H_0(1+q_t)}{Z}-\dfrac{1}{Z}\displaystyle\sum_{i=1}^ZH_i=\dfrac{\bar H_0(1+q_t)}{Z}-H_{0ср} $$
# Если невязка получается отрицательной - ступени считаются разгруженными, если - положительной, то перегруженными.
# Перегруженные ступени в среднем имеют большее КПД на переменных режимах.

# %%
# 11 Величина распределения теплоперепадов дробной ступени на остальные
Delta_H = (fH_0*(1+q_t)/Z.m) - H_0ave

# %%
Math(
    API.lstr(r"11.\ \Delta_H = \dfrac{\bar H_0(1+q_t)}{Z}-H_{0ср}=\dfrac{[fH_0](1+[q_t])}{[Z]}-[H_0ave] = [Delta_H]").dformat(fH_0=fH_0,q_t=q_t,Z=Z,H_0ave=H_0ave,Delta_H=Delta_H).get_large()
)
# Out:
# $\displaystyle \Large{11.\ \Delta_H = \dfrac{\bar H_0(1+q_t)}{Z}-H_{0ср}=\dfrac{316.1(1+0.00246)}{6}-52.49 = 0.315} \\ \ \\$

# %% [markdown]
# ### 12. Уточнее теплоперепадов с учетом невязки
# $$ \large{H_{новi} = H_i + \Delta_H}$$

# %%
# 12 Уточненные теплоперепады
H_new_vec = H_vec + Delta_H

# %%
H_new_vec_str = r""
for i in range(0, len(H_new_vec)):
    H_new_vec_str += API.lstr( r"H_{нов[i]}=H_{[i]} + \Delta_H = [H_i] + [Delta_H] = [H_new]\ кДж/кг").dformat(i=i+1,H_i=H_vec[i],Delta_H=Delta_H,H_new=H_new_vec[i]).get_large()
    
Math(
    API.lstr(r"\Large{12. }\\") + 
    H_new_vec_str
)
# Out:
# $\displaystyle \Large{12. }\\\Large{H_{нов1}=H_{1} + \Delta_H = 50.43 + 0.315 = 50.74\ кДж/кг} \\ \ \\\Large{H_{нов2}=H_{2} + \Delta_H = 51.16 + 0.315 = 51.47\ кДж/кг} \\ \ \\\Large{H_{нов3}=H_{3} + \Delta_H = 51.97 + 0.315 = 52.28\ кДж/кг} \\ \ \\\Large{H_{нов4}=H_{4} + \Delta_H = 52.84 + 0.315 = 53.16\ кДж/кг} \\ \ \\\Large{H_{нов5}=H_{5} + \Delta_H = 53.78 + 0.315 = 54.1\ кДж/кг} \\ \ \\\Large{H_{нов6}=H_{6} + \Delta_H = 54.78 + 0.315 = 55.1\ кДж/кг} \\ \ \\$

# %%
def get_index_offset_value(in_vec):
    delta = (in_vec[1] - in_vec[0]).m
    offset_start = in_vec[0].m
    offset_it = 0

    while(offset_start > 0):
        offset_start -= delta
        offset_it += 1
    offset_start += delta
    return [delta, -offset_it*delta]
    
# Графики    
fig,axs = plt.subplots(figsize=(15,40),nrows=7, ncols=1)

# Для зависимости диаметров
axs[0].plot(stages_number_vec, d_vec.m, **{'marker': 'D'}, color='orange')
axs[0].set_xlabel('Номер ступени: $Z_{i}, []$')
axs[0].set_ylabel("Средний диаметр ступени: $d_{i}$, [м]", **{'fontname':'sans-serif'})
#axs[0].set_ylim([0,None])
#axs[0].text(1.5,0.837, 'Общее количество ступеней: $Z={}$'.format(Z), **{'fontname':'DejaVu Sans'})
plot_delta_d, plot_offset_d = get_index_offset_value(d_vec)
axs[0].yaxis.set_major_locator(ticker.IndexLocator(base=plot_delta_d, offset= 0))
axs[0].xaxis.set_major_locator(ticker.IndexLocator(base=1, offset=0))
axs[0].grid(True)

# # Для зависимости высот лопаток
axs[1].plot(stages_number_vec, l_vec, **{'marker': 'D'}, color='orange')
axs[1].set_xlabel('Номер ступени: $Z_{i}, []$')
axs[1].set_ylabel('Высота рабочей лопатки: $l_{i}$, [м]', **{'fontname':'sans-serif'})
axs[1].set_ylim([0,None])
# plot_delta_l = l_vec[1] - l_vec[0]
# #plot_delta_l = l_fun_handler.get_no_dim(2) - l_fun_handler.get_no_dim(1)
# offset_l = l_vec[0].m
# offset_it = 0
# while(offset_l > 0):
#     offset_l -= plot_delta_l.m
#     offset_it += 1
# offset_l +=plot_delta_l.m

plot_delta_l, plot_offset_l = get_index_offset_value(l_vec)
axs[1].yaxis.set_major_locator(ticker.IndexLocator(base=plot_delta_l, offset=plot_offset_l))
#axs[1].yaxis.set_major_locator(ticker.LinearLocator())
axs[1].xaxis.set_major_locator(ticker.IndexLocator(base=1, offset=0))
axs[1].grid(True)

# Для обратной веерности
axs[2].plot(stages_number_vec, theta_vec, **{'marker': 'D'}, color='orange')
axs[2].set_xlabel('Номер ступени: $Z_{i}, []$')
axs[2].set_ylabel('Обратная веерность: $\\theta_{i}$, []', **{'fontname':'sans-serif'})
axs[2].yaxis.set_minor_locator(ticker.MultipleLocator(5))
axs[2].minorticks_on()
axs[2].xaxis.set_minor_locator(plt.NullLocator())
axs[2].xaxis.set_major_locator(ticker.IndexLocator(base=1, offset=0))
axs[2].grid(True)

# Для степени реактивности
axs[3].plot(stages_number_vec, rho_vec, **{'marker': 'D'}, color='orange')
axs[3].set_xlabel('Номер ступени: $Z_{i}, []$')
axs[3].set_ylabel('Степень реактивности: $\\rho_{i}$, []', **{'fontname':'sans-serif'})
axs[3].xaxis.set_major_locator(ticker.IndexLocator(base=1, offset=0))
plot_delta_rho = rho_vec[1] - rho_vec[0]
axs[3].yaxis.set_minor_locator(ticker.MultipleLocator(5))
axs[3].minorticks_on()
axs[3].xaxis.set_minor_locator(plt.NullLocator())
axs[3].grid(True)

# Для отношения U/c_f
axs[4].plot(stages_number_vec, uDIVc_f_vec, **{'marker': 'D'}, color='orange')
axs[4].set_xlabel('Номер ступени: $Z_{i}, []$')
axs[4].set_ylabel('$(u/c_{ф})_{i}$, []', **{'fontname':'sans-serif'})
axs[4].minorticks_on()
axs[4].xaxis.set_major_locator(ticker.IndexLocator(base=1, offset=0))
axs[4].yaxis.set_minor_locator(ticker.MultipleLocator(5))
axs[4].xaxis.set_minor_locator(plt.NullLocator())
axs[4].grid(True)

# Для теплоперепадов
axs[5].plot(stages_number_vec, H_vec, **{'marker': 'D'}, color='orange')
axs[5].set_xlabel('Номер ступени: $Z_{i}, []$')
axs[5].set_ylabel('$H_i$, [кДж/кг]', **{'fontname':'sans-serif'})
#axs[5].xaxis.set_major_locator(ticker.IndexLocator(base=1, offset=0))
axs[5].minorticks_on()
axs[5].xaxis.set_minor_locator(plt.NullLocator())

#axs[5].yaxis.set_minor_locator(ticker.MultipleLocator(Z.m + 2))

axs[5].grid(True)

# Для теплоперепадов с учетом невязки
axs[6].plot(stages_number_vec, H_new_vec, **{'marker': 'D'}, color='orange')
axs[6].set_xlabel('Номер ступени: $Z_{i}, []$')
axs[6].set_ylabel('$H_{i} + \\Delta$, [кДж/кг]', **{'fontname':'sans-serif'})
axs[6].minorticks_on()
#axs[6].xaxis.set_major_locator(ticker.IndexLocator(base=1, offset=0))
#axs[6].yaxis.set_minor_locator(ticker.MultipleLocator(Z.m + 2))
axs[6].xaxis.set_minor_locator(plt.NullLocator())


axs[6].grid(True)
# Out:
# c:\prog\py\lib\site-packages\matplotlib\cbook\__init__.py:1369: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)

# %%
with open('tex/split.tex',encoding='utf-8') as file:
    lines = file.readlines()
    new_text = ""
    for line in lines:
        new_text += line
    
    d_vec_str = ''
    l_vec_str = ''
    theta_vec_str = ''
    rho_vec_str = ''
    H_vec_str = ''
    uDIVc_opt_vec_str = ''
    H_new_vec_str = ''
    for i in range(0, len(d_vec)):
        d_vec_str += API.lstr(r"d_{[it]} & = k_d z_{[it]} + b_d = [k_d] \cdot [z] + [b_d] = [d_i]\ м ").dlformat(it=i+1,z=i+1,d_i=d_vec[i],k_d=k_d,b_d=b_d)
        l_vec_str += API.lstr(r"l_{[it]} & = k_l z_{[it]} + b_l = [k_l] \cdot [z] + [b_l] = [l_i]\ м ").dlformat(it=i+1,k_l=k_l,z=i+1,b_l=b_l,l_i=l_vec[i])
        theta_vec_str += API.lstr(r"\theta_{[i]} & = \frac{l_{[i]} + d_к}{l_{[i]}} = \frac{[l_i] + [d_k]}{[l_i]}=[theta]").dlformat(i=i+1,theta=theta_vec[i],l_i=l_vec[i],d_k=d_k)
        rho_vec_str += API.lstr(r"\rho_{[i]} & =\rho_к+\frac{1.8}{1.8+\theta_{[i]}}=[rho_k]+\frac{1.8}{1.8+[theta_i]}=[rho_i]").dlformat(i=i+1,rho_k=rho_k,theta_i=theta_vec[i],rho_i=rho_vec[i])
        uDIVc_opt_vec_str += API.lstr(r"\left(\frac{u}{c_ф}\right)_{[i]} & = \frac{\varphi\cos{\alpha_{1эф}}}{2\sqrt{1-\rho_{[i]}}} = \frac{[phi]\cos{[alpha_1eef]^\circ}}{2\sqrt{1-[rho_i]}}=[uDIVc_i]").dlformat(i=i+1,phi=phi,alpha_1eef=alpha_1eef,rho_i=rho_vec[i],uDIVc_i=uDIVc_f_vec[i])
        H_vec_str += API.lstr(r"H_{0[i]} & = 12300 \left(\frac{d_[i]}{(u/c_ф)_{опт[i]}} \frac{n}{50}\right)^2K_[i] = 12300\left(\frac{[d_i]}{[uDIVc_i]}\frac{[n]}{50}\right)^2[K_i]=[H_0i]\ кДж/кг ").dlformat(i=i+1,d_i=d_vec[i],n=n,K_i=K_vec[i],uDIVc_i=uDIVc_f_vec[i],H_0i=H_vec[i])
        H_new_vec_str += API.lstr( r"H_{нов[i]}& =H_{[i]} + \Delta_H = [H_i] + [Delta_H] = [H_new]\ кДж/кг").dformat(i=i+1,H_i=H_vec[i],Delta_H=Delta_H,H_new=H_new_vec[i])
        
        if i == len(d_vec) - 1:
            pass
        else:
            d_vec_str += r"\\"
            l_vec_str += r"\\"
            theta_vec_str += r"\\"
            rho_vec_str += r"\\"
            H_vec_str += r"\\"
            uDIVc_opt_vec_str += r"\\"
            H_new_vec_str += r"\\"
        
    H_0_sum_str = API.lstr(r"[a]").dformat(a=H_vec[0])
    for i in range(1, len(H_vec)):
        H_0_sum_str += API.lstr("+[a]").dformat(a=H_vec[i])
    
    # Графики
    d_vec_str_plot = ''
    for i,item in enumerate(d_vec.m):
        d_vec_str_plot += '({},{})'.format(i+1,item)
    
    l_vec_str_plot = ''
    for i,item in enumerate(l_vec.m):
        l_vec_str_plot += '({},{})'.format(i+1,item)
    
    theta_vec_str_plot = ''
    for i,item in enumerate(theta_vec.m):
        theta_vec_str_plot += '({},{})'.format(i+1,item)
    
    rho_vec_str_plot = ''
    for i,item in enumerate(rho_vec.m):
        rho_vec_str_plot += '({},{})'.format(i+1,item)
     
    X_vec_str_plot = ''
    for i,item in enumerate(uDIVc_f_vec.m):
        X_vec_str_plot += '({},{})'.format(i+1,item)
    
    H_0_vec_str_plot = ''
    for i,item in enumerate(H_vec.m):
        H_0_vec_str_plot += '({},{})'.format(i+1,item)
    
    H_new_vec_str_plot = ''
    for i,item in enumerate(H_new_vec.m):
        H_new_vec_str_plot += '({},{})'.format(i+1,item)
    
    
    all_text = API.lstr(new_text)
    all_text = all_text.dformat(
         number=number,
         fp_0=fp_0,
         fh_0=fh_0,
         n=n,
         G_0=G_0,
         p_z=p_z,
         eta_oi=etaHPC_oi,
         eta=etaHPC_oi,
         rho_k=rho_k,
         alpha_1eef=alpha_1eef,
         phi=phi,
         mu=mu,
         Delta=Delta,
         Z=Z,
         d_1=d_1,
         fs_0=fs_0,
         theta=theta,
         rho=rho,
         uDIVc_f=uDIVu_cf,
         fH_01=fH_01,
         h_2t=h_2t,
         v_2t=v_2t,
         percent_difference=percent_difference,
         iterations_number=iterations_number,
         d_k=d_k,
         l_21=l_21,
         h_zt=h_zt,
         fH_0=fH_0,
         l_11=l_11,
         H_i=H_i,
         h_z=h_z,
         v_2z=v_2z,
         d_21=d_1,
         l_2z=l_2z,
         d_2z=d_2z,
         theta_1=theta_1,
         theta_z=theta_z,
         rho_1=rho_1,
         rho_z=rho_z,
         k_d=k_d,
         b_d=b_d,
         k_l=k_l,
         b_l=b_l,
         H_0ave=H_0ave,
         q_t=q_t,
         Z_new=Z_new,
         Delta_H=Delta_H,
         uDIVc_1=uDIVu_1,
         uDIVc_z=uDIVu_z,
         d_z=d_2z,
         l_z=l_2z,
         d_vec_str=d_vec_str,
         l_vec_str=l_vec_str,
         theta_vec_str=theta_vec_str,
         rho_vec_str=rho_vec_str,
         uDIVc_opt_vec_str=uDIVc_opt_vec_str,
         H_vec_str=H_vec_str,
         H_new_vec_str=H_new_vec_str,
         H_0sum_str=H_0_sum_str,
         #d_vec_str_plot=d_vec_str_plot
    )
         
    all_text = all_text.performat(
        d_vec_str_plot=d_vec_str_plot,
        l_vec_str_plot=l_vec_str_plot,
        theta_vec_str_plot=theta_vec_str_plot,
        rho_vec_str_plot=rho_vec_str_plot,
        X_vec_str_plot=X_vec_str_plot,
        H_0_vec_str_plot=H_0_vec_str_plot,
        H_new_vec_str_plot=H_new_vec_str_plot
    )     
         
         
            
    
with open('tex/split_paste_2.tex','w', encoding='utf-8')as file:
    file.write(str(all_text))
